# %%
#reuters
from tensorflow.keras.datasets import reuters
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)

# %% [markdown]
# ## Preprocess Data

# %%
word_index = reuters.get_word_index()
 
# Inverting the word index dictionary to decode indices back to words
index_to_word = {index: word for word, index in word_index.items()}
 
# Decoding function
def decode_review(encoded_review):
    return ' '.join([index_to_word.get(i - 3, '?') for i in encoded_review])
 
# Decode the train and test data
train_texts = [decode_review(sequence) for sequence in train_data]
test_texts = [decode_review(sequence) for sequence in test_data]
 
# Create pandas DataFrames
train_df = pd.DataFrame({
    'text': train_texts,
    'label': train_labels
})
 
test_df = pd.DataFrame({
    'text': test_texts,
    'label': test_labels
})
 
# Display the first few rows of the train DataFrame
print(train_df.head())
# Out:
#                                                 text  label
# 0  ? ? ? said as a result of its december acquisi...      3
# 1  ? generale de banque sa lt ? br and lt heller ...      4
# 2  ? shr 3 28 dlrs vs 22 cts shr diluted 2 99 dlr...      3
# 3  ? the farmers home administration the u s agri...      4
# 4  ? seton co said its board has received a propo...      4

# %%
train_df
# Out:
#                                                    text  label
# 0     ? ? ? said as a result of its december acquisi...      3
# 1     ? generale de banque sa lt ? br and lt heller ...      4
# 2     ? shr 3 28 dlrs vs 22 cts shr diluted 2 99 dlr...      3
# 3     ? the farmers home administration the u s agri...      4
# 4     ? seton co said its board has received a propo...      4
# ...                                                 ...    ...
# 8977  ? finance minister kiichi miyazawa said japan ...     19
# 8978  ? the price of gold bullion is likely to rise ...     19
# 8979  ? international phoenix energy corp said it la...     25
# 8980  ? shr loss 76 cts vs profit 50 cts net loss 19...      3
# 8981  ? currency fluctuations may ? their influence ...     25
#
# [8982 rows x 2 columns]

# %%
test_df
# Out:
#                                                    text  label
# 0     ? the great atlantic and pacific tea co said i...      3
# 1     ? philippine sugar production in the 1987 88 c...     10
# 2     ? the agriculture department's widening of lou...      1
# 3     ? ? ? oil and gas partnership said it complete...      4
# 4     ? strong south ? winds were keeping many vesse...      4
# ...                                                 ...    ...
# 2241  ? lt toronto sun publishing corp said it plann...      3
# 2242  ? shr loss 45 cts vs profit 20 cts net loss 1 ...      8
# 2243  ? sept 30 shr 44 cts net 905 000 vs 631 000 si...      3
# 2244  ? inland ? inc said is board proposed a two fo...      3
# 2245  ? congress should give the u s agriculture sec...     24
#
# [2246 rows x 2 columns]

# %% [markdown]
# ## Generating Embeddings

# %%
# FastText embeddings

from gensim.models import FastText
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import remove_stopwords
from nltk.stem import WordNetLemmatizer

# Tokenize the text
def preprocess(text):
    return [
        WordNetLemmatizer().lemmatize(token)
        for token in simple_preprocess(remove_stopwords(text))
    ]

# Preprocess the train and test data
train_df['text'] = train_df['text'].apply(preprocess)
test_df['text'] = test_df['text'].apply(preprocess)

# %%
train_df
# Out:
#                                                    text  label
# 0     [said, result, december, acquisition, space, e...      3
# 1     [generale, banque, sa, lt, br, lt, heller, ove...      4
# 2     [shr, dlrs, v, ct, shr, diluted, dlrs, v, ct, ...      3
# 3     [farmer, home, administration, agriculture, de...      4
# 4     [seton, said, board, received, proposal, chair...      4
# ...                                                 ...    ...
# 8977  [finance, minister, kiichi, miyazawa, said, ja...     19
# 8978  [price, gold, bullion, likely, rise, second, h...     19
# 8979  [international, phoenix, energy, corp, said, l...     25
# 8980  [shr, loss, ct, v, profit, ct, net, loss, v, p...      3
# 8981  [currency, fluctuation, influence, bullion, ma...     25
#
# [8982 rows x 2 columns]

# %%
# tokenize the text
FastText_model = FastText(train_df['text'])

# %%
#embedding
def vectorize(text):
    vectors = [FastText_model.wv[word] for word in text if word in FastText_model.wv]
    return np.mean(vectors, axis=0) if vectors else np.zeros(FastText_model.vector_size)

# Vectorize the train and test data
X_train = np.stack(train_df['text'].apply(vectorize))
X_test = np.stack(test_df['text'].apply(vectorize))

# %%
X_train.shape
# Out:
# (8982, 100)

# %%
from tensorflow.keras.utils import to_categorical

# One-hot encode the labels
y_train = to_categorical(train_df['label'])
y_test = to_categorical(test_df['label'])

# %%
y_train.shape
# Out:
# (8982, 46)

# %% [markdown]
# ## Model Training

# %%
#train val split
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2)

# %%
from keras.callbacks import LearningRateScheduler, ModelCheckpoint
import os
import tensorflow as tf

# %%
# Checkpoints -- Saves the best MOdel
model_name = "NN.keras"
checkpoint = ModelCheckpoint(model_name,
                            monitor="val_loss",
                            mode="min",
                            save_best_only = True,
                            verbose=2)

# %%
# Defining Tensorflow Model (Edit: Added Dropout Layers to deal with overfitting)
model = Sequential()
model.add(Dense(64, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(46, activation='softmax'))
epochs = 100

# %%
# Learning Rate Scheduler -- Change Learning Rate after 70% of epochs
def learning_rate(epoch, lr):
    if epoch < 0.7 * epochs:
        return lr
    else:
        return float(lr * tf.math.exp(-0.009))

lr_scheduler = LearningRateScheduler(learning_rate)
model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=epochs, batch_size=132, validation_data= (X_val, y_val), callbacks = [lr_scheduler,checkpoint ])
# Out:
# Epoch 1/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3157 - loss: 3.0811
# Epoch 1: val_loss improved from inf to 1.68435, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3182 - loss: 3.0702 - val_accuracy: 0.5982 - val_loss: 1.6843 - learning_rate: 0.0010
# Epoch 2/100
# 51/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6177 - loss: 1.6337
# Epoch 2: val_loss improved from 1.68435 to 1.45520, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6187 - loss: 1.6301 - val_accuracy: 0.6728 - val_loss: 1.4552 - learning_rate: 0.0010
# Epoch 3/100
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6683 - loss: 1.4713
# Epoch 3: val_loss improved from 1.45520 to 1.34776, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6687 - loss: 1.4648 - val_accuracy: 0.6784 - val_loss: 1.3478 - learning_rate: 0.0010
# Epoch 4/100
# 38/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6802 - loss: 1.3404
# Epoch 4: val_loss improved from 1.34776 to 1.27989, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6812 - loss: 1.3446 - val_accuracy: 0.6917 - val_loss: 1.2799 - learning_rate: 0.0010
# Epoch 5/100
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6882 - loss: 1.3179
# Epoch 5: val_loss improved from 1.27989 to 1.23041, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6907 - loss: 1.3092 - val_accuracy: 0.7017 - val_loss: 1.2304 - learning_rate: 0.0010
# Epoch 6/100
# 52/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7015 - loss: 1.2655
# Epoch 6: val_loss improved from 1.23041 to 1.19573, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7015 - loss: 1.2649 - val_accuracy: 0.7017 - val_loss: 1.1957 - learning_rate: 0.0010
# Epoch 7/100
# 37/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6981 - loss: 1.2595
# Epoch 7: val_loss improved from 1.19573 to 1.17334, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7006 - loss: 1.2460 - val_accuracy: 0.7051 - val_loss: 1.1733 - learning_rate: 0.0010
# Epoch 8/100
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7070 - loss: 1.1975
# Epoch 8: val_loss improved from 1.17334 to 1.13914, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7078 - loss: 1.2016 - val_accuracy: 0.7106 - val_loss: 1.1391 - learning_rate: 0.0010
# Epoch 9/100
# 51/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7174 - loss: 1.1705
# Epoch 9: val_loss improved from 1.13914 to 1.12371, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7175 - loss: 1.1713 - val_accuracy: 0.7151 - val_loss: 1.1237 - learning_rate: 0.0010
# Epoch 10/100
# 50/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7217 - loss: 1.1372
# Epoch 10: val_loss improved from 1.12371 to 1.10285, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7215 - loss: 1.1390 - val_accuracy: 0.7262 - val_loss: 1.1028 - learning_rate: 0.0010
# Epoch 11/100
# 37/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7133 - loss: 1.1490
# Epoch 11: val_loss improved from 1.10285 to 1.09609, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7167 - loss: 1.1445 - val_accuracy: 0.7223 - val_loss: 1.0961 - learning_rate: 0.0010
# Epoch 12/100
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7211 - loss: 1.1295
# Epoch 12: val_loss improved from 1.09609 to 1.07940, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7214 - loss: 1.1293 - val_accuracy: 0.7273 - val_loss: 1.0794 - learning_rate: 0.0010
# Epoch 13/100
# 50/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7326 - loss: 1.1229
# Epoch 13: val_loss improved from 1.07940 to 1.07159, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7324 - loss: 1.1226 - val_accuracy: 0.7284 - val_loss: 1.0716 - learning_rate: 0.0010
# Epoch 14/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7237 - loss: 1.1277
# Epoch 14: val_loss improved from 1.07159 to 1.06060, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7239 - loss: 1.1273 - val_accuracy: 0.7295 - val_loss: 1.0606 - learning_rate: 0.0010
# Epoch 15/100
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7291 - loss: 1.1116
# Epoch 15: val_loss improved from 1.06060 to 1.05201, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7306 - loss: 1.1058 - val_accuracy: 0.7351 - val_loss: 1.0520 - learning_rate: 0.0010
# Epoch 16/100
# 50/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7348 - loss: 1.0936
# Epoch 16: val_loss improved from 1.05201 to 1.04235, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7350 - loss: 1.0926 - val_accuracy: 0.7373 - val_loss: 1.0423 - learning_rate: 0.0010
# Epoch 17/100
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7406 - loss: 1.0950
# Epoch 17: val_loss improved from 1.04235 to 1.03573, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7402 - loss: 1.0917 - val_accuracy: 0.7373 - val_loss: 1.0357 - learning_rate: 0.0010
# Epoch 18/100
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7394 - loss: 1.0579
# Epoch 18: val_loss improved from 1.03573 to 1.02642, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7399 - loss: 1.0584 - val_accuracy: 0.7357 - val_loss: 1.0264 - learning_rate: 0.0010
# Epoch 19/100
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7415 - loss: 1.0345
# Epoch 19: val_loss improved from 1.02642 to 1.02549, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7413 - loss: 1.0380 - val_accuracy: 0.7423 - val_loss: 1.0255 - learning_rate: 0.0010
# Epoch 20/100
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7371 - loss: 1.0883
# Epoch 20: val_loss improved from 1.02549 to 1.02091, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7381 - loss: 1.0823 - val_accuracy: 0.7418 - val_loss: 1.0209 - learning_rate: 0.0010
# Epoch 21/100
# 49/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7388 - loss: 1.0490
# Epoch 21: val_loss improved from 1.02091 to 1.01418, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7392 - loss: 1.0489 - val_accuracy: 0.7435 - val_loss: 1.0142 - learning_rate: 0.0010
# Epoch 22/100
# 35/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7468 - loss: 1.0399
# Epoch 22: val_loss did not improve from 1.01418
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7459 - loss: 1.0383 - val_accuracy: 0.7407 - val_loss: 1.0152 - learning_rate: 0.0010
# Epoch 23/100
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7249 - loss: 1.1018
# Epoch 23: val_loss improved from 1.01418 to 1.00849, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7296 - loss: 1.0879 - val_accuracy: 0.7423 - val_loss: 1.0085 - learning_rate: 0.0010
# Epoch 24/100
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7428 - loss: 1.0362
# Epoch 24: val_loss improved from 1.00849 to 1.00080, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7428 - loss: 1.0355 - val_accuracy: 0.7412 - val_loss: 1.0008 - learning_rate: 0.0010
# Epoch 25/100
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7425 - loss: 1.0601
# Epoch 25: val_loss did not improve from 1.00080
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7447 - loss: 1.0519 - val_accuracy: 0.7468 - val_loss: 1.0028 - learning_rate: 0.0010
# Epoch 26/100
# 51/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7464 - loss: 1.0540
# Epoch 26: val_loss did not improve from 1.00080
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7466 - loss: 1.0520 - val_accuracy: 0.7485 - val_loss: 1.0026 - learning_rate: 0.0010
# Epoch 27/100
# 51/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7402 - loss: 1.0269
# Epoch 27: val_loss improved from 1.00080 to 0.99336, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7407 - loss: 1.0263 - val_accuracy: 0.7501 - val_loss: 0.9934 - learning_rate: 0.0010
# Epoch 28/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7503 - loss: 0.9983
# Epoch 28: val_loss did not improve from 0.99336
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7503 - loss: 0.9986 - val_accuracy: 0.7479 - val_loss: 0.9984 - learning_rate: 0.0010
# Epoch 29/100
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7539 - loss: 1.0176
# Epoch 29: val_loss improved from 0.99336 to 0.98873, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7538 - loss: 1.0170 - val_accuracy: 0.7490 - val_loss: 0.9887 - learning_rate: 0.0010
# Epoch 30/100
# 41/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7500 - loss: 0.9943
# Epoch 30: val_loss improved from 0.98873 to 0.98173, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7509 - loss: 0.9941 - val_accuracy: 0.7468 - val_loss: 0.9817 - learning_rate: 0.0010
# Epoch 31/100
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7594 - loss: 0.9796
# Epoch 31: val_loss improved from 0.98173 to 0.97738, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7580 - loss: 0.9845 - val_accuracy: 0.7496 - val_loss: 0.9774 - learning_rate: 0.0010
# Epoch 32/100
# 51/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7382 - loss: 1.0357
# Epoch 32: val_loss did not improve from 0.97738
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7393 - loss: 1.0328 - val_accuracy: 0.7507 - val_loss: 0.9805 - learning_rate: 0.0010
# Epoch 33/100
# 44/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7520 - loss: 1.0090
# Epoch 33: val_loss improved from 0.97738 to 0.97672, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7513 - loss: 1.0089 - val_accuracy: 0.7496 - val_loss: 0.9767 - learning_rate: 0.0010
# Epoch 34/100
# 49/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7563 - loss: 0.9815
# Epoch 34: val_loss improved from 0.97672 to 0.97430, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7557 - loss: 0.9831 - val_accuracy: 0.7462 - val_loss: 0.9743 - learning_rate: 0.0010
# Epoch 35/100
# 47/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7648 - loss: 0.9586
# Epoch 35: val_loss improved from 0.97430 to 0.96783, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7635 - loss: 0.9638 - val_accuracy: 0.7551 - val_loss: 0.9678 - learning_rate: 0.0010
# Epoch 36/100
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7599 - loss: 0.9667
# Epoch 36: val_loss did not improve from 0.96783
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7596 - loss: 0.9692 - val_accuracy: 0.7535 - val_loss: 0.9685 - learning_rate: 0.0010
# Epoch 37/100
# 41/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7509 - loss: 1.0158
# Epoch 37: val_loss did not improve from 0.96783
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7512 - loss: 1.0105 - val_accuracy: 0.7513 - val_loss: 0.9718 - learning_rate: 0.0010
# Epoch 38/100
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7722 - loss: 0.9430
# Epoch 38: val_loss improved from 0.96783 to 0.96701, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7696 - loss: 0.9498 - val_accuracy: 0.7507 - val_loss: 0.9670 - learning_rate: 0.0010
# Epoch 39/100
# 49/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7500 - loss: 0.9931
# Epoch 39: val_loss did not improve from 0.96701
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7506 - loss: 0.9919 - val_accuracy: 0.7529 - val_loss: 0.9713 - learning_rate: 0.0010
# Epoch 40/100
# 51/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7605 - loss: 0.9715
# Epoch 40: val_loss improved from 0.96701 to 0.96120, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7602 - loss: 0.9726 - val_accuracy: 0.7563 - val_loss: 0.9612 - learning_rate: 0.0010
# Epoch 41/100
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7602 - loss: 0.9808
# Epoch 41: val_loss improved from 0.96120 to 0.95970, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7597 - loss: 0.9817 - val_accuracy: 0.7557 - val_loss: 0.9597 - learning_rate: 0.0010
# Epoch 42/100
# 48/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7561 - loss: 0.9643
# Epoch 42: val_loss did not improve from 0.95970
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7568 - loss: 0.9646 - val_accuracy: 0.7557 - val_loss: 0.9647 - learning_rate: 0.0010
# Epoch 43/100
# 37/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7598 - loss: 0.9745
# Epoch 43: val_loss improved from 0.95970 to 0.95511, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7592 - loss: 0.9741 - val_accuracy: 0.7540 - val_loss: 0.9551 - learning_rate: 0.0010
# Epoch 44/100
# 47/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7568 - loss: 1.0033
# Epoch 44: val_loss did not improve from 0.95511
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7571 - loss: 0.9995 - val_accuracy: 0.7557 - val_loss: 0.9634 - learning_rate: 0.0010
# Epoch 45/100
# 44/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7592 - loss: 0.9871
# Epoch 45: val_loss did not improve from 0.95511
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7593 - loss: 0.9840 - val_accuracy: 0.7524 - val_loss: 0.9577 - learning_rate: 0.0010
# Epoch 46/100
# 29/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7692 - loss: 0.9222
# Epoch 46: val_loss did not improve from 0.95511
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7651 - loss: 0.9443 - val_accuracy: 0.7602 - val_loss: 0.9553 - learning_rate: 0.0010
# Epoch 47/100
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7633 - loss: 0.9300
# Epoch 47: val_loss improved from 0.95511 to 0.95105, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7630 - loss: 0.9317 - val_accuracy: 0.7585 - val_loss: 0.9510 - learning_rate: 0.0010
# Epoch 48/100
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7664 - loss: 0.9510
# Epoch 48: val_loss improved from 0.95105 to 0.94999, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7663 - loss: 0.9515 - val_accuracy: 0.7602 - val_loss: 0.9500 - learning_rate: 0.0010
# Epoch 49/100
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7525 - loss: 0.9653
# Epoch 49: val_loss did not improve from 0.94999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7527 - loss: 0.9652 - val_accuracy: 0.7563 - val_loss: 0.9539 - learning_rate: 0.0010
# Epoch 50/100
# 47/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7685 - loss: 0.9383
# Epoch 50: val_loss improved from 0.94999 to 0.94921, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7674 - loss: 0.9417 - val_accuracy: 0.7613 - val_loss: 0.9492 - learning_rate: 0.0010
# Epoch 51/100
# 38/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7571 - loss: 0.9696
# Epoch 51: val_loss did not improve from 0.94921
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7589 - loss: 0.9668 - val_accuracy: 0.7613 - val_loss: 0.9511 - learning_rate: 0.0010
# Epoch 52/100
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7614 - loss: 0.9409
# Epoch 52: val_loss improved from 0.94921 to 0.94901, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7613 - loss: 0.9447 - val_accuracy: 0.7596 - val_loss: 0.9490 - learning_rate: 0.0010
# Epoch 53/100
# 38/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7546 - loss: 0.9657
# Epoch 53: val_loss improved from 0.94901 to 0.94867, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7566 - loss: 0.9634 - val_accuracy: 0.7613 - val_loss: 0.9487 - learning_rate: 0.0010
# Epoch 54/100
# 35/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7622 - loss: 0.9432
# Epoch 54: val_loss did not improve from 0.94867
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7626 - loss: 0.9436 - val_accuracy: 0.7568 - val_loss: 0.9561 - learning_rate: 0.0010
# Epoch 55/100
# 48/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7686 - loss: 0.9445
# Epoch 55: val_loss did not improve from 0.94867
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7683 - loss: 0.9445 - val_accuracy: 0.7602 - val_loss: 0.9520 - learning_rate: 0.0010
# Epoch 56/100
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7584 - loss: 0.9841
# Epoch 56: val_loss did not improve from 0.94867
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7601 - loss: 0.9745 - val_accuracy: 0.7590 - val_loss: 0.9504 - learning_rate: 0.0010
# Epoch 57/100
# 48/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7526 - loss: 0.9623
# Epoch 57: val_loss improved from 0.94867 to 0.94595, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7536 - loss: 0.9605 - val_accuracy: 0.7635 - val_loss: 0.9460 - learning_rate: 0.0010
# Epoch 58/100
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7650 - loss: 0.9296
# Epoch 58: val_loss improved from 0.94595 to 0.94386, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7656 - loss: 0.9297 - val_accuracy: 0.7602 - val_loss: 0.9439 - learning_rate: 0.0010
# Epoch 59/100
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7677 - loss: 0.9437
# Epoch 59: val_loss did not improve from 0.94386
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7677 - loss: 0.9434 - val_accuracy: 0.7574 - val_loss: 0.9646 - learning_rate: 0.0010
# Epoch 60/100
# 34/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7566 - loss: 0.9748
# Epoch 60: val_loss improved from 0.94386 to 0.94342, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7584 - loss: 0.9668 - val_accuracy: 0.7674 - val_loss: 0.9434 - learning_rate: 0.0010
# Epoch 61/100
# 41/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7556 - loss: 1.0022
# Epoch 61: val_loss did not improve from 0.94342
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7575 - loss: 0.9909 - val_accuracy: 0.7629 - val_loss: 0.9470 - learning_rate: 0.0010
# Epoch 62/100
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7635 - loss: 0.9316
# Epoch 62: val_loss did not improve from 0.94342
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7647 - loss: 0.9313 - val_accuracy: 0.7652 - val_loss: 0.9453 - learning_rate: 0.0010
# Epoch 63/100
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7737 - loss: 0.9044
# Epoch 63: val_loss improved from 0.94342 to 0.93882, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7732 - loss: 0.9100 - val_accuracy: 0.7679 - val_loss: 0.9388 - learning_rate: 0.0010
# Epoch 64/100
# 45/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7636 - loss: 0.9246
# Epoch 64: val_loss did not improve from 0.93882
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7641 - loss: 0.9273 - val_accuracy: 0.7629 - val_loss: 0.9392 - learning_rate: 0.0010
# Epoch 65/100
# 48/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7671 - loss: 0.9142
# Epoch 65: val_loss did not improve from 0.93882
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7665 - loss: 0.9162 - val_accuracy: 0.7657 - val_loss: 0.9427 - learning_rate: 0.0010
# Epoch 66/100
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7576 - loss: 0.9486
# Epoch 66: val_loss did not improve from 0.93882
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7594 - loss: 0.9461 - val_accuracy: 0.7679 - val_loss: 0.9396 - learning_rate: 0.0010
# Epoch 67/100
# 50/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7712 - loss: 0.9189
# Epoch 67: val_loss did not improve from 0.93882
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7707 - loss: 0.9202 - val_accuracy: 0.7668 - val_loss: 0.9391 - learning_rate: 0.0010
# Epoch 68/100
# 38/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7647 - loss: 0.9206
# Epoch 68: val_loss improved from 0.93882 to 0.93852, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7631 - loss: 0.9281 - val_accuracy: 0.7685 - val_loss: 0.9385 - learning_rate: 0.0010
# Epoch 69/100
# 45/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7766 - loss: 0.8988
# Epoch 69: val_loss did not improve from 0.93852
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7747 - loss: 0.9039 - val_accuracy: 0.7674 - val_loss: 0.9393 - learning_rate: 0.0010
# Epoch 70/100
# 25/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7663 - loss: 0.9556
# Epoch 70: val_loss did not improve from 0.93852
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7656 - loss: 0.9419 - val_accuracy: 0.7685 - val_loss: 0.9427 - learning_rate: 0.0010
# Epoch 71/100
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7618 - loss: 0.9365
# Epoch 71: val_loss improved from 0.93852 to 0.93735, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7620 - loss: 0.9356 - val_accuracy: 0.7691 - val_loss: 0.9374 - learning_rate: 9.9104e-04
# Epoch 72/100
# 50/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7660 - loss: 0.9117
# Epoch 72: val_loss improved from 0.93735 to 0.93627, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7660 - loss: 0.9134 - val_accuracy: 0.7679 - val_loss: 0.9363 - learning_rate: 9.8216e-04
# Epoch 73/100
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7723 - loss: 0.9076
# Epoch 73: val_loss did not improve from 0.93627
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7708 - loss: 0.9121 - val_accuracy: 0.7668 - val_loss: 0.9437 - learning_rate: 9.7336e-04
# Epoch 74/100
# 38/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7741 - loss: 0.8839
# Epoch 74: val_loss improved from 0.93627 to 0.93058, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7737 - loss: 0.8936 - val_accuracy: 0.7679 - val_loss: 0.9306 - learning_rate: 9.6464e-04
# Epoch 75/100
# 51/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7656 - loss: 0.9336
# Epoch 75: val_loss did not improve from 0.93058
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7658 - loss: 0.9335 - val_accuracy: 0.7691 - val_loss: 0.9355 - learning_rate: 9.5600e-04
# Epoch 76/100
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7726 - loss: 0.9033
# Epoch 76: val_loss did not improve from 0.93058
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7718 - loss: 0.9076 - val_accuracy: 0.7674 - val_loss: 0.9366 - learning_rate: 9.4743e-04
# Epoch 77/100
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7737 - loss: 0.8914
# Epoch 77: val_loss did not improve from 0.93058
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7729 - loss: 0.8935 - val_accuracy: 0.7718 - val_loss: 0.9351 - learning_rate: 9.3894e-04
# Epoch 78/100
# 44/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7686 - loss: 0.9235
# Epoch 78: val_loss did not improve from 0.93058
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7682 - loss: 0.9228 - val_accuracy: 0.7763 - val_loss: 0.9319 - learning_rate: 9.3053e-04
# Epoch 79/100
# 41/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7682 - loss: 0.9384
# Epoch 79: val_loss did not improve from 0.93058
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7684 - loss: 0.9353 - val_accuracy: 0.7707 - val_loss: 0.9343 - learning_rate: 9.2219e-04
# Epoch 80/100
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7671 - loss: 0.9236
# Epoch 80: val_loss improved from 0.93058 to 0.92795, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7671 - loss: 0.9234 - val_accuracy: 0.7707 - val_loss: 0.9280 - learning_rate: 9.1393e-04
# Epoch 81/100
# 47/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7577 - loss: 0.9404
# Epoch 81: val_loss did not improve from 0.92795
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7596 - loss: 0.9354 - val_accuracy: 0.7718 - val_loss: 0.9352 - learning_rate: 9.0574e-04
# Epoch 82/100
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7771 - loss: 0.9044
# Epoch 82: val_loss did not improve from 0.92795
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7769 - loss: 0.9048 - val_accuracy: 0.7718 - val_loss: 0.9322 - learning_rate: 8.9763e-04
# Epoch 83/100
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7771 - loss: 0.8742
# Epoch 83: val_loss did not improve from 0.92795
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7753 - loss: 0.8846 - val_accuracy: 0.7674 - val_loss: 0.9354 - learning_rate: 8.8959e-04
# Epoch 84/100
# 32/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7645 - loss: 0.9127
# Epoch 84: val_loss did not improve from 0.92795
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7646 - loss: 0.9151 - val_accuracy: 0.7713 - val_loss: 0.9344 - learning_rate: 8.8162e-04
# Epoch 85/100
# 25/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7681 - loss: 0.9049
# Epoch 85: val_loss did not improve from 0.92795
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7687 - loss: 0.9122 - val_accuracy: 0.7718 - val_loss: 0.9364 - learning_rate: 8.7372e-04
# Epoch 86/100
# 27/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7648 - loss: 0.9557
# Epoch 86: val_loss did not improve from 0.92795
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7687 - loss: 0.9340 - val_accuracy: 0.7696 - val_loss: 0.9326 - learning_rate: 8.6589e-04
# Epoch 87/100
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7677 - loss: 0.9258
# Epoch 87: val_loss improved from 0.92795 to 0.92542, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7679 - loss: 0.9247 - val_accuracy: 0.7746 - val_loss: 0.9254 - learning_rate: 8.5813e-04
# Epoch 88/100
# 37/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7743 - loss: 0.9008
# Epoch 88: val_loss did not improve from 0.92542
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7750 - loss: 0.9001 - val_accuracy: 0.7735 - val_loss: 0.9266 - learning_rate: 8.5044e-04
# Epoch 89/100
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7703 - loss: 0.9072
# Epoch 89: val_loss did not improve from 0.92542
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7693 - loss: 0.9085 - val_accuracy: 0.7724 - val_loss: 0.9371 - learning_rate: 8.4282e-04
# Epoch 90/100
# 29/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7755 - loss: 0.8471
# Epoch 90: val_loss improved from 0.92542 to 0.92217, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7741 - loss: 0.8712 - val_accuracy: 0.7724 - val_loss: 0.9222 - learning_rate: 8.3527e-04
# Epoch 91/100
# 37/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7694 - loss: 0.9201
# Epoch 91: val_loss did not improve from 0.92217
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7683 - loss: 0.9192 - val_accuracy: 0.7696 - val_loss: 0.9298 - learning_rate: 8.2779e-04
# Epoch 92/100
# 49/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7743 - loss: 0.8966
# Epoch 92: val_loss did not improve from 0.92217
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7742 - loss: 0.8986 - val_accuracy: 0.7752 - val_loss: 0.9231 - learning_rate: 8.2037e-04
# Epoch 93/100
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7764 - loss: 0.8862
# Epoch 93: val_loss did not improve from 0.92217
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7751 - loss: 0.8923 - val_accuracy: 0.7752 - val_loss: 0.9278 - learning_rate: 8.1302e-04
# Epoch 94/100
# 49/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7657 - loss: 0.9293
# Epoch 94: val_loss did not improve from 0.92217
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7663 - loss: 0.9269 - val_accuracy: 0.7696 - val_loss: 0.9302 - learning_rate: 8.0574e-04
# Epoch 95/100
# 47/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7823 - loss: 0.8657
# Epoch 95: val_loss did not improve from 0.92217
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7806 - loss: 0.8716 - val_accuracy: 0.7741 - val_loss: 0.9251 - learning_rate: 7.9852e-04
# Epoch 96/100
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7823 - loss: 0.8697
# Epoch 96: val_loss did not improve from 0.92217
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7805 - loss: 0.8742 - val_accuracy: 0.7735 - val_loss: 0.9285 - learning_rate: 7.9136e-04
# Epoch 97/100
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7695 - loss: 0.9193
# Epoch 97: val_loss did not improve from 0.92217
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7696 - loss: 0.9164 - val_accuracy: 0.7735 - val_loss: 0.9289 - learning_rate: 7.8427e-04
# Epoch 98/100
# 49/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7801 - loss: 0.8630
# Epoch 98: val_loss did not improve from 0.92217
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7790 - loss: 0.8682 - val_accuracy: 0.7735 - val_loss: 0.9291 - learning_rate: 7.7725e-04
# Epoch 99/100
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7779 - loss: 0.8861
# Epoch 99: val_loss did not improve from 0.92217
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7769 - loss: 0.8910 - val_accuracy: 0.7735 - val_loss: 0.9254 - learning_rate: 7.7028e-04
# Epoch 100/100
# 44/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7812 - loss: 0.8645
# Epoch 100: val_loss improved from 0.92217 to 0.92139, saving model to NN.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7796 - loss: 0.8724 - val_accuracy: 0.7763 - val_loss: 0.9214 - learning_rate: 7.6338e-04

# %% [markdown]
# ## Evaluation

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 5))

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()

# %%
import tensorflow as tf
from sklearn.metrics import accuracy_score, classification_report

# %%
# Load the best model
loaded_model = tf.keras.models.load_model(model_name)

# Predict the test data
y_pred = loaded_model.predict(X_test, verbose=0)
y_pred_train = loaded_model.predict(X_train, verbose = 0)

# %%
#accuracies
train_acc = accuracy_score([np.argmax(i) for i in y_train],[np.argmax(i) for i in y_pred_train])
test_acc = accuracy_score([np.argmax(i) for i in y_test],[np.argmax(i) for i in y_pred])

# plot
plt.figure(figsize=(14, 5))
plt.bar(['Train', 'Test'], [train_acc, test_acc])
plt.ylabel('Accuracy')
plt.title('Train vs Test Accuracy')
for i, v in enumerate([train_acc, test_acc]):
    plt.text(i, v + 0.01, str(round(v, 2)), ha='center')
plt.show()

# %%
y_test, y_pred = [np.argmax(i) for i in y_test],[np.argmax(i) for i in y_pred]
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2246
#
#     accuracy                           1.00      2246
#    macro avg       1.00      1.00      1.00      2246
# weighted avg       1.00      1.00      1.00      2246
